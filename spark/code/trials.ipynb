
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import SparkSession 
from pyspark.sql.functions import from_json, col, create_map, unix_timestamp
from pyspark.sql.types import *
from pyspark.sql import DataFrame
from pyspark.ml.regression import LinearRegression 
from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector
from pyspark.sql import Row
import datetime

def clean_raw_data(raw: DataFrame) -> DataFrame:
  time_format = "yyyy-MM-dd'T'HH:mm:ss.SSS'Z'"
  return raw.select(
    col('@timestamp').cast('timestamp'), 
    col('FM'), 
    col('PI'), 
    col('RSSI').cast('long'), 
    col('coords'), 
    col('province'), 
    col('station_name')) \
  .withColumn('milliseconds', unix_timestamp('@timestamp', format=time_format))

def attach_feature_as_vectors(dataframe) -> DataFrame:
  to_vector = lambda millis: Vectors.dense([millis])
  milliseconds_to_vec = udf(to_vector, VectorUDT())
  return dataframe.withColumn('millis_vec', milliseconds_to_vec(dataframe.milliseconds))

def get_linear_regression_model(training_set):
  lr = LinearRegression(
    maxIter=10, 
    regParam=0.3, 
    elasticNetParam=0.8, 
    featuresCol='millis_vec', 
    labelCol='RSSI'
  )
  return lr.fit(training_set)

spark = SparkSession \
  .builder \
    .appName('rssi_signal_prediction') \
      .getOrCreate()

spark.sparkContext.setLogLevel("WARN")
raw_data = spark.createDataFrame(js)
df = clean_raw_data(raw_data)
# training = get_data_as_libsvm(df)
training = attach_feature_as_vectors(df)

lastSignalMilliseconds = training.agg({'milliseconds': 'max'}).collect()[0]['max(milliseconds)']
# print(lastSignalMilliseconds)

pr1 = lastSignalMilliseconds + (60000 * 1)
pr2 = lastSignalMilliseconds + (60000 * 2)
pr3 = lastSignalMilliseconds + (60000 * 3)
pr4 = lastSignalMilliseconds + (60000 * 4)
pr5 = lastSignalMilliseconds + (60000 * 5)

linear_model = get_linear_regression_model(training)

# rowToPredict = Row(millis_vec=Vectors.dense([pr1]))
# rowToPredict = Row(millis_vec=DenseVector([pr1]))
print(linear_model.predict(Vectors.dense([pr1])))

print("Coefficients: %s" % str(linear_model.coefficients))
print("Intercept: %s" % str(linear_model.intercept))
# print(summary)
# print(training.head().millis_vec)
# print(lrModel.predict(training.head().millis_vec))
# training.head()
# print(df.milliseconds.max())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-65.03389830508475
# Coefficients: [0.0]
# Intercept: -65.03389830508475
# </div>

# %%
from pyspark.mllib.regression import LabeledPoint 

encode = lambda row: LabeledPoint(row['RSSI'], [row['milliseconds']])
c = df.rdd 
d = c.map(encode)
print(d.take(3))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from pyspark.sql.functions import to_timestamp, col

ndf = df.select("@timestamp", "FM", "PI", "RSSI", "coords", "province", "station_name").withColumn("@timestamp", to_timestamp("@timestamp", "yyyy-MM-dd'T'HH:mm:ss.SSS'Z'")).withColumn("RSSI", col("RSSI").cast("long"))
ndf.describe()
ndf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import pandas as pd

from pyspark.sql.functions import pandas_udf
from pyspark.sql.functions import PandasUDFType

#schema = StructType() \
#  .add("@timestamp", TimestampType()) \
#  .add("RSSI", LongType()) \
#  .add("province", StringType()) \
#  .add("station_name", StringType()) \
#  .add("FM", StringType()) \
#  .add("coords", StringType()) \
#  .add("PI", StringType(), True)

schema = StructType() \
  .add("province", StringType())

@pandas_udf(schema, functionType=PandasUDFType.GROUPED_MAP)
def g(df):
    result = pd.DataFrame(df.groupby(df.province).apply(
        lambda x: x
    ))
    #result.reset_index(inplace=True, drop=False)
    return result

tmp = ndf.select("province")
k = tmp.groupBy("province").apply(g)
k.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
